# %% [markdown]
# # Consolidated NGO/Non-profit Organizations

# %%
import pandas as pd
import numpy as np

# %%
# downloaded from https://www.dropbox.com/s/jeot82hhvo04b1x/Cosolidated%20NGO%20list.xlsx?dl=0
fn = "data/Cosolidated NGO list.xlsx"
all_ngo =  pd.read_excel(fn)

# %%
## See all the column names
garbage = [print(col) for col in all_ngo.columns]
# Out:
# Link
# Ngo Name
# Year of Establishment
# GuideStar URL
# Full Time Staff
# Full Time Volunteers
# Collected
# Target
# Donations
# Description
# Vision
# Solution
# Long-Term Impact
# ngo url
# Facebook
# Twitter
# Fax
# PAN
# Mobile
# Registration number / CIN & registration date
# 12A registration number & registration date
# 80G registration number & registration date
# FCRA registration number & registration date
# 35AC registration number & registration date
# Annual budget
# Total income
# Total expenditure
# Average monthly expenditure
# Total fixed assets
# Long term loan
# Total funding gap
# Number of full time employees
# Number of part time employees
# Number of consultants
# Number of volunteers / interns
# Which operational area do you require additional help with?
# Number of board members
# Number of meetings done
# Governance photos
# Governance documents
# Who are your major funders?
# Name your funders
# Project start date
# Project end/expected close date
# ...

# %%
all_ngo['PAN'].value_counts()
# Out:
# 1234567890    82
# AAAAA7573K    12
# AAAAH7132F    11
# AAAAA9461E     9
# AAAAE2969D     7
# AAAAD7321C     6
# AAAAH7396F     6
# AAATI2569Q     6
# AAMTS2499F     5
# AAAAG2194C     4
# AAAAG8812D     4
# AAATF0985D     3
# AAATS4205P     3
# AACTA7903L     3
# AAAAA6003E     3
# AAATE3547N     2
# AACTA4128R     2
# AAATC2665F     2
# AABTP7408C     2
# AAATD1358A     2
# AABTM1421G     2
# AAATD5274D     2
# AAATL9638D     2
# AAFFD1185N     2
# AABTP2065R     2
# AAATP7242D     2
# AAATA3756F     2
# AAAJS0017P     2
# AAATE1354P     2
# AABTM3571H     2
#               ..
# AADTA1587F     1
# AABAL0801C     1
# AAATE3280G     1
# AAQTS2029H     1
# AAATA7817K     1
# AAEAT2861K     1
# AACTG1821F     1
# AAQTS3439P     1
# AAAAM9283E     1
# AAACH2843M     1
# AAATC4491R     1
# AADTS3830P     1
# AABTP4668E     1
# AACTS7528R     1
# AAATL8429Q     1
# AAAAY0462F     1
# AAGTS5567C     1
# AAFTS4504E     1
# AAATI0384D     1
# AAHCM3245P     1
# AAATV3469J     1
# ...

# %%
## we suspected PAN should've been unique per NGO, but  there  are 12  instances of  AAAAA7573K....
## we're  not sure why...
twleve = 'AAAAA7573K'
all_ngo[all_ngo['PAN']==twleve].head()
# Out:
#                                                  Link  \
# 9   http://www.ngoimpact.com/ngos/anjani-education...
# 25      http://www.ngoimpact.com/ngos/aarohan#profile
# 34       http://www.ngoimpact.com/ngos/aawhan#profile
# 51        http://www.ngoimpact.com/ngos/aider#profile
# 98  http://www.ngoimpact.com/ngos/being-social-fou...
#
#                                              Ngo Name  Year of Establishment  \
# 9   Anjani Education Trust Best Non-Government Org...                    NaN
# 25  Aarohan Best Non-Government Organizations & So...                    NaN
# 34  AAWHAN Best Non-Government Organizations & Soc...                    NaN
# 51  AIDER Best Non-Government Organizations & Soci...                    NaN
# 98  Being Social Foundation Best Non-Government Or...                    NaN
#
#    GuideStar URL Full Time Staff  Full Time Volunteers Collected Target  \
# 9            NaN             NaN                   NaN       NaN    NaN
# ...

# %%
all_ngo['ngo url'].value_counts()
# Out:
# http://ngo.india.gov.in                              434
# https://ngodarpan.gov.in/index.php/ngo/primaryngo    117
# http://www.ngo.india.gov.in                           79
# http://ngodarpan.gov.in/index.php/ngo/primaryngo      51
# https://ngodarpan.gov.in                              44
# http://ngodarpan.gov.in                               41
# http://www.facebook.com                               38
# http://ngo.india.in                                   32
# http://ngoindia.gov.in                                30
# http://www.bajss.org                                  20
# http://www.serudsindia.org                            15
# http://jss.nic.in                                     15
# http://ngo.in                                         14
# http://www.theiab.org                                 14
# http://maccia.org.in                                  13
# http://yahoo.com                                      13
# ...
